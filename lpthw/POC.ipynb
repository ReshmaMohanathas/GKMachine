# %%
import pandas as pd 
import matplotlib.pyplot as plt
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])#left,bottom,width,height
ax2=fig.add_axes([1.2,0,1,1])
# ax3=fig.add_axes([0,-1.2,1,1])
# ax4=fig.add_axes([1.2,-1.2,1,1])


data=pd.read_csv("C:\\Users\\gokul\\OneDrive\\Documents\\Resh\\logs.csv",names=["Internal ID","CID","PID","Brand","APP Name","APP-Version","Platform","Card Type-Msg"])
data.drop("APP-Version",axis=1,inplace=True)
data.rename(columns={"Card Type-Msg":"Card_Type_Msg","APP Name":"APP_Name"},inplace=True)
data[["Card Type","Msg"]]=data.Card_Type_Msg.str.split("] -",expand=True)
data.drop("Card_Type_Msg",axis=1,inplace=True)
data["Platform"]=data["Platform"].str[10:]
data["APP_Name"]=data["APP_Name"].str[10:]
data["Msg"]=data["Msg"].str[21:]

# fig, (ax1,ax2,ax3,ax4)=plt.subplots(nrows=2,ncols=2)
# data.groupby(["Platform","APP_Name"])["APP_Name"].count().plot(kind='bar',ax=ax1,label="plot1",use_index=True)
data.groupby("Platform")["APP_Name"].count().plot(kind='bar',ax=ax2,color='red',label="plot2")
data.groupby("Msg")["PID"].count().plot(kind="barh",ax=ax1,label="plot3")
# data.groupby("Msg")["PID"].count().plot(kind="barh",ax=ax4,label="plot4")
ax1.legend(loc="best")
# ax1.set_xticklabels(ax1.get_xticks(), rotation = 0)
# plt.xticks(range(len(values)), keys,rotation=90)
# ax1.set_xlabel("xaxis")
# ax2.set_xlabel("x")
# ax1.set_ylabel("Number of users")

# %%
import pandas as pd 
import matplotlib.pyplot as plt
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])#left,bottom,width,height
ax2=fig.add_axes([1.2,0,1,1])
# ax3=fig.add_axes([0,-1.2,1,1])
# ax4=fig.add_axes([1.2,-1.2,1,1])


data=pd.read_csv("C:\\Users\\OneDrive\\Documents\\Resh\\logs.csv",names=["Internal ID","CID","PID","Brand","APP Name","APP-Version","Platform","Card Type-Msg"])
data.drop("APP-Version",axis=1,inplace=True)
data.rename(columns={"Card Type-Msg":"Card_Type_Msg","APP Name":"APP_Name"},inplace=True)
data[["Card Type","Msg"]]=data.Card_Type_Msg.str.split("] -",expand=True)
data.drop("Card_Type_Msg",axis=1,inplace=True)
data["Platform"]=data["Platform"].str[10:]
data["APP_Name"]=data["APP_Name"].str[10:]
data["Msg"]=data["Msg"].str[21:]

# fig, (ax1,ax2,ax3,ax4)=plt.subplots(nrows=2,ncols=2)
# data.groupby(["Platform","APP_Name"])["APP_Name"].count().plot(kind='bar',ax=ax1,label="plot1",use_index=True)
data.groupby("Platform")["APP_Name"].count().plot(kind='bar',ax=ax2,color='red',label="plot2")
data.groupby("Msg")["PID"].count().plot(kind="barh",ax=ax1,label="plot3")
# data.groupby("Msg")["PID"].count().plot(kind="barh",ax=ax4,label="plot4")
ax1.legend(loc="best")
# ax1.set_xticklabels(ax1.get_xticks(), rotation = 0)
# plt.xticks(range(len(values)), keys,rotation=90)
# ax1.set_xlabel("xaxis")
# ax2.set_xlabel("x")
# ax1.set_ylabel("Number of users")

# %%
fig=plt.figure()
fig, (ax1,ax2,ax3,ax4)=plt.subplots(nrows=2,ncols=2)

data.groupby(["Platform","APP_Name"])["APP_Name"].count().plot(kind='bar',ax=ax1)
data.groupby("Platform")["APP_Name"].count().plot(kind='bar',ax=ax2,color='red')
ax1.set_xlabel("xaxis")
ax2.set_xlabel("x")
ax1.set_ylabel("Number of users")
data.groupby("Msg")["PID"].count().plot(kind="barh",ax=ax3)
data.groupby("Msg")["PID"].count().plot(kind="barh",ax=ax4)
# data.groupby(["Platform","APP_Name"])["APP_Name"].count().plot(x='',kind='bar')
# df2=data.groupby(["Platform","Card Type"]).sum().plot()
#df1.plot(kind='bar',x='APP Name' ,use_index=True)

# %%
data.groupby("Msg")["PID"].count().plot(kind="barh")

# %% [markdown]
# fig=plt.figure()
# ax1=plt.subplot(121)
# ax2=plt.subplot(122)
# ax1=data.groupby(["Platform","APP_Name"])["APP_Name"].count().plot(kind='bar',)
# ax2=data.groupby("Platform")["APP_Name"].count().plot(kind='bar',)
# ax1.set_xlabel("xaxis")
# ax2.set_xlabel("x")

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])#left,bottom,width,height
ax2=fig.add_axes([1.2,0,1,1])
ax3=fig.add_axes([2.4,0,1,1])
ax4=fig.add_axes([1.2,-1.2,1,1])
ax1.plot()
