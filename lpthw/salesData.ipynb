# %%
import pandas as pd

df=pd.read_excel("C:\\Users\\gokul\\OneDrive\\Documents\\Resh\\sales_data.xlsx","Orders")
df.groupby("Region")[["Sales","Profit"]].sum().plot(kind="bar",title="bar graph",subplots=True)
# Out:
# array([<Axes: title={'center': 'Sales'}, xlabel='Region'>,
#        <Axes: title={'center': 'Profit'}, xlabel='Region'>], dtype=object)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')
